# %%
from seaborn import load_dataset

from analyticplots import bar_plot

# %%
data = load_dataset("flights")

# %%
bar_plot(data.reset_index(), x="year", y="passengers",
         hue="month", title="best plot")
